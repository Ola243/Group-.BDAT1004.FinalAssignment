# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("roman-emperor-reigns copy.xlsx")

# %%
df.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
df.shape
# Out:
# (68, 3)

# %%
death_cause = df.sort_values(by = ['Cause_of_Death'])

# %%
print(death_cause)
# Out:
#                Emperor  Length_of_Reign Cause_of_Death
# 26         Maximinus I             3.25   Assassinated
# 35  Trebonianus Gallus             2.00   Assassinated
# 18            Pertinax             0.25   Assassinated
# 17            Commodus            15.00   Assassinated
# 24          Elagabalus             3.75   Assassinated
# ..                 ...              ...            ...
# 55        Maximinus II             2.00        Suicide
# 49            Maximian            19.00        Suicide
# 6                 Otho             0.25        Suicide
# 4                 Nero            13.67        Suicide
# 27           Gordian I             0.06        Suicide
#
# [68 rows x 3 columns]

# %%
death = df['Cause_of_Death'].values.tolist()

# %%
print(death)
# Out:
# ['Possibly assassinated', 'Possibly assassinated', 'Assassinated', 'Possibly assassinated', 'Suicide', 'Assassinated', 'Suicide', 'Assassinated', 'Natural causes', 'Illness', 'Assassinated', 'Natural causes', 'Natural causes', 'Natural causes', 'Natural causes', 'Illness', 'Illness', 'Assassinated', 'Assassinated', 'Executed', 'Natural causes', 'Assassinated', 'Assassinated', 'Executed', 'Assassinated', 'Assassinated', 'Assassinated', 'Suicide', 'Killed in battle', 'Assassinated', 'Assassinated', 'Possibly assassinated', 'Killed in battle', 'Killed in battle', 'Illness', 'Assassinated', 'Assassinated', 'Died in captivity', 'Assassinated', 'Illness', 'Possibly assassinated', 'Assassinated', 'Possibly assassinated', 'Assassinated', 'Assassinated', 'Natural causes', 'Possibly assassinated', 'Killed in battle', 'Natural causes', 'Suicide', 'Natural causes', 'Natural causes', 'Assassinated', 'Natural causes', 'Killed in battle', 'Suicide', 'Executed', 'Killed in battle', 'Natural causes',
# ...

# %%
plot = df.plot.pie(y='Length_of_Reign', figsize =(10,10))

# %%
plot = plt.figure(figsize=(10,10))
df.groupby(['Emperor']).sum().plot(kind = 'pie', y = 'Length_of_Reign', autopct = '%1.0f%%')
# Out:
# C:\Users\Bonn_arts\AppData\Local\Temp\ipykernel_3864\3997704507.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Emperor']).sum().plot(kind = 'pie', y = 'Length_of_Reign', autopct = '%1.0f%%')
# <AxesSubplot: ylabel='Length_of_Reign'>
