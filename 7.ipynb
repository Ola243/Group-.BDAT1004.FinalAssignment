# %%
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('us-marriages-divorces-1867-2014 copy.xlsx')

# %%
df.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
df.iloc[33]
# Out:
# Year                      1900.0
# Marriages               709000.0
# Divorces                 56000.0
# Population            76094000.0
# Marriages_per_1000           9.3
# Divorces_per_1000            0.7
# Name: 33, dtype: float64

# %%
df.iloc[83]
# Out:
# Year                       1950.0
# Marriages               1667000.0
# Divorces                 385000.0
# Population            151684000.0
# Marriages_per_1000           11.0
# Divorces_per_1000             2.5
# Name: 83, dtype: float64

# %%
df.iloc[133]
# Out:
# Year                       2000.0
# Marriages               2315000.0
# Divorces                 944000.0
# Population            282398000.0
# Marriages_per_1000            8.2
# Divorces_per_1000             3.3
# Name: 133, dtype: float64

# %%
df.iloc[133].plot( kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
df.iloc[83].plot( kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
df.iloc[33].plot( kind = 'bar')
# Out:
# <AxesSubplot: >
